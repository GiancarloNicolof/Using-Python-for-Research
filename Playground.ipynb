# %%
import copy
x = [1,[2]]
y = copy.copy(x)
z = copy.deepcopy(x)
y is z
# Out:
# False

# %%
n=100
number_of_times = 0
while n >= 1:
    n //= 2
    number_of_times += 1
print(number_of_times)
# Out:
# 7

# %%
oddNumbers = [0, 1, 3, 5, 7, 9]
sum(oddNumbers)
# Out:
# 25

# %%
sum([i for i in range(10) if i % 2 == 1])
# Out:
# 25

# %%
def modify(mylist):
    mylist[0] *= 10
    return(mylist)
L = [1, 3, 5, 7, 9]
M = modify(L)
M is L
# Out:
# True

# %%
def is_vowel(letter):
    if type(letter) == int:
        letter = str(letter)
    if letter in "aeiouy":
        return(True)
    else:
        return(False)

is_vowel(4)
# Out:
# False

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([0,1,4,9,16])

# %%
x = np.linspace(0, 10, 20)
y1 = x**2.0
y2 = x**1.5

# %%
plt.plot(x, y1, "bo-", linewidth=2, markersize=6)

# %%
plt.plot(x, y2, "gs-", linewidth=2, markersize=8)

# %%
plt.plot(x, y1, "bo-", linewidth=2, markersize=6, label="First")
plt.plot(x, y2, "gs-", linewidth=2, markersize=8, label="Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")

# %%
x = np.logspace(-1, 1, 40)
y1 = x**2.0
y2 = x**1.5
plt.loglog(x, y1, "bo-", linewidth=2, markersize=6, label="First")
plt.loglog(x, y2, "gs-", linewidth=2, markersize=8, label="Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
# Out:
# /var/folders/qk/qkn_2c9n7rx2lyqkkthnv7w00000gn/T/ipykernel_78620/1788214363.py:8: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.axis([-0.5, 10.5, -5, 105])
# /var/folders/qk/qkn_2c9n7rx2lyqkkthnv7w00000gn/T/ipykernel_78620/1788214363.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.axis([-0.5, 10.5, -5, 105])

# %%
x = np.random.normal(size=1000)
plt.hist(x, density=True, bins=np.linspace(-5, 5, 21))
# Out:
# (array([0.   , 0.   , 0.   , 0.   , 0.01 , 0.022, 0.082, 0.206, 0.306,
#         0.376, 0.35 , 0.326, 0.186, 0.1  , 0.03 , 0.004, 0.002, 0.   ,
#         0.   , 0.   ]),
#  array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#          0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ]),
#  <BarContainer object of 20 artists>)

# %%
x = np.random.gamma(2, 3, 100000)
plt.hist(x, bins=30, density=True);

# %%
plt.figure()
plt.subplot(221)
plt.hist(x, bins=30)
plt.subplot(222)
plt.hist(x, bins=30, density=True)
plt.subplot(223)
plt.hist(x, bins=30, cumulative=True)
plt.subplot(224)
plt.hist(x, bins=30, density=True, cumulative=True, histtype="step");
