# %%
import copy
x = [1,[2]]
y = copy.copy(x)
z = copy.deepcopy(x)
y is z
# Out:
# False

# %%
n=100
number_of_times = 0
while n >= 1:
    n //= 2
    number_of_times += 1
print(number_of_times)
# Out:
# 7

# %%
oddNumbers = [0, 1, 3, 5, 7, 9]
sum(oddNumbers)
# Out:
# 25

# %%
sum([i for i in range(10) if i % 2 == 1])
# Out:
# 25

# %%
def modify(mylist):
    mylist[0] *= 10
    return(mylist)
L = [1, 3, 5, 7, 9]
M = modify(L)
M is L
# Out:
# True

# %%
def is_vowel(letter):
    if type(letter) == int:
        letter = str(letter)
    if letter in "aeiouy":
        return(True)
    else:
        return(False)

is_vowel(4)
# Out:
# False

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([0,1,4,9,16]);

# %%
x = np.linspace(0, 10, 20)
y1 = x**2.0
y2 = x**1.5

# %%
plt.plot(x, y1, "bo-", linewidth=2, markersize=6);

# %%
plt.plot(x, y2, "gs-", linewidth=2, markersize=8);

# %%
plt.plot(x, y1, "bo-", linewidth=2, markersize=6, label="First")
plt.plot(x, y2, "gs-", linewidth=2, markersize=8, label="Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left");

# %%
x = np.logspace(-1, 1, 40)
y1 = x**2.0
y2 = x**1.5
plt.loglog(x, y1, "bo-", linewidth=2, markersize=6, label="First")
plt.loglog(x, y2, "gs-", linewidth=2, markersize=8, label="Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left");
# Out:
# /var/folders/qk/qkn_2c9n7rx2lyqkkthnv7w00000gn/T/ipykernel_93717/1477426143.py:8: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.axis([-0.5, 10.5, -5, 105])
# /var/folders/qk/qkn_2c9n7rx2lyqkkthnv7w00000gn/T/ipykernel_93717/1477426143.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.axis([-0.5, 10.5, -5, 105])

# %%
x = np.random.normal(size=1000)
plt.hist(x, density=True, bins=np.linspace(-5, 5, 21));

# %%
x = np.random.gamma(2, 3, 100000)
plt.hist(x, bins=30, density=True);

# %%
plt.figure()
plt.subplot(221)
plt.hist(x, bins=30)
plt.subplot(222)
plt.hist(x, bins=30, density=True)
plt.subplot(223)
plt.hist(x, bins=30, cumulative=True)
plt.subplot(224)
plt.hist(x, bins=30, density=True, cumulative=True, histtype="step");

# %%
import random

# %%
random.choice(range(1,7))
# Out:
# 6

# %%
random.choice(list([1,2,3,4]))
# Out:
# 1

# %%
rolls = [random.choice([1,2,3,4,5,6]) for i in range(10000)]
plt.hist(rolls, bins = np.linspace(0.5, 6.5, 7));

# %%
ys = []
for rep in range(10000):
    y = 0
    for k in range(10):
        x = random.choice([1,2,3,4,5,6])
        y += x
    ys.append(y)

# %%
plt.hist(ys);

# %%
X = np.random.randint(1, 7, (10000, 10))
Y = np.sum(X, axis=1)
plt.hist(Y);

# %%
delta_X = np.random.normal(0, 1, (2,5))
plt.plot(delta_X[0], delta_X[1], "go");

# %%
X = np.cumsum(delta_X, axis=1)
plt.plot(X[0], X[1], "ro-");

# %%
X_0 = np.array([[0], [0]])
X2= np.concatenate((X_0, X), axis=1)
plt.plot(X2[0], X2[1], "ro-");
